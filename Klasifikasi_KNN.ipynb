# %% [markdown]
# <a href="https://colab.research.google.com/github/ryssofficial/Praktikum-1-AI-Linear-Regression-Google-Colab/blob/KNN-Clasification/Klasifikasi_KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %%
iris = load_iris()
X_iris, y_iris = iris.data, iris.target
X_train, X_test, y_train, y_test = train_test_split(X_iris, y_iris, test_size=0.2)

# %%
knn_iris = KNeighborsClassifier(n_neighbors=3)
knn_iris.fit(X_train, y_train)
print(f"Akurasi KNN Iris: {knn_iris.score(X_test, y_test)}")
# Out:
# Akurasi KNN Iris: 0.9666666666666667
